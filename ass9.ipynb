# %%
'''
 Data Visualization II 
1. Use the inbuilt dataset 'titanic' as used in the above problem. Plot a box plot for distribution 
of age with respect to each gender along with the information about whether they survived 
or not. (Column names : 'sex' and 'age') 
2. Write observations on the inference from the above statistics
'''
# Out:
# "\n Data Visualization II \n1. Use the inbuilt dataset 'titanic' as used in the above problem. Plot a box plot for distribution \nof age with respect to each gender along with the information about whether they survived \nor not. (Column names : 'sex' and 'age') \n2. Write observations on the inference from the above statistics\n"

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic["age"].fillna(titanic["age"].mean(),inplace=True)
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_18924\2475312687.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic["age"].fillna(titanic["age"].mean(),inplace=True)

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
fig, axes = plt.subplots(1,2)
sns.boxplot( ax=axes[0],data = titanic, y ='age',)
sns.boxplot( ax=axes[1],data = titanic, y ='fare',)
plt.show()

# %%
fig, axes = plt.subplots(1,3, sharey=True)
sns.boxplot( ax=axes[0],data = titanic, x='sex', y ='age', hue = 'sex',)
sns.boxplot( ax=axes[1],data = titanic, x='pclass', y ='age', hue = 'pclass',)
sns.boxplot(ax=axes[2],data = titanic, x='survived', y ='age', hue = 'survived', )
plt.show()
# sharey=True tells Matplotlib to: Share the same y-axis scale across all 3 plots.

# %%
fig, axes = plt.subplots(1,3, sharey=True)
sns.boxplot( ax=axes[0],data = titanic, x='sex', y ='fare', hue = 'sex', log_scale = True)
sns.boxplot( ax=axes[1], data = titanic, x='pclass', y ='fare', hue = 'pclass',log_scale = True)
sns.boxplot(ax=axes[2],data = titanic, x='survived', y ='fare', hue = 'survived',  log_scale = True)
plt.show()

#  Why use log_scale=True:
#    The fare column in the Titanic dataset has a few extremely high values (outliers), while most values are much lower. This causes:
#    A compressed boxplot, where you can’t see the details of most data points.
#    By applying a log scale:
#    It spreads out the smaller values.
#    Compresses the large outliers.
#    Makes the plot easier to read and interpret.

# %%
fig, axes = plt.subplots(1,3, sharey=True)
sns.boxplot( ax=axes[0],data = titanic, x='sex', y ='fare', hue = 'sex')
sns.boxplot( ax=axes[1], data = titanic, x='pclass', y ='fare', hue = 'pclass')
sns.boxplot(ax=axes[2],data = titanic, x='survived', y ='fare', hue = 'survived')
plt.show()

# %%
fig, axes = plt.subplots(1,2, sharey=True)
sns.boxplot(ax=axes[0],data = titanic, x='sex', y ='age', hue = 'survived')
sns.boxplot(ax=axes[1],data = titanic, x='pclass', y ='age', hue = 'survived' )
plt.show()

# %%
fig, axes = plt.subplots(1,2, sharey=True)
sns.boxplot(ax=axes[0], data = titanic, x='sex', y ='fare', hue = 'survived', log_scale = True)
sns.boxplot(ax=axes[1],data = titanic, x='pclass', y ='fare', hue = 'survived',  log_scale = True)
plt.show()
